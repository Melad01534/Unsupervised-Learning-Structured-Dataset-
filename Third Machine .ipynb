# %%
import pandas as pd

# %%
df = pd.read_csv('players_22.csv')
df
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_27032\151137848.py:1: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('players_22.csv')
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# ...

# %%
df.describe()
# Out:
#            sofifa_id       overall     potential     value_eur       wage_eur  \
# count   19239.000000  19239.000000  19239.000000  1.916500e+04   19178.000000
# mean   231468.086959     65.772182     71.079370  2.850452e+06    9017.989363
# std     27039.717497      6.880232      6.086213  7.613700e+06   19470.176724
# min        41.000000     47.000000     49.000000  9.000000e+03     500.000000
# 25%    214413.500000     61.000000     67.000000  4.750000e+05    1000.000000
# 50%    236543.000000     66.000000     71.000000  9.750000e+05    3000.000000
# 75%    253532.500000     70.000000     75.000000  2.000000e+06    8000.000000
# max    264640.000000     93.000000     95.000000  1.940000e+08  350000.000000
#
#                 age     height_cm     weight_kg   club_team_id  league_level  \
# count  19239.000000  19239.000000  19239.000000   19178.000000  19178.000000
# mean      25.210822    181.299704     74.943032   50580.498123      1.354364
# ...

# %%
sorted_df = df.sort_values(by=df.columns[0])
sorted_df
# Out:
#        sofifa_id                                         player_url  \
# 509           41  https://sofifa.com/player/41/andres-iniesta-lu...
# 388         1179  https://sofifa.com/player/1179/gianluigi-buffo...
# 1136        2147  https://sofifa.com/player/2147/maarten-stekele...
# 16505       2702  https://sofifa.com/player/2702/kevin-ellison/2...
# 3827        3467  https://sofifa.com/player/3467/yuri-de-souza-f...
# ...          ...                                                ...
# 16995     264631  https://sofifa.com/player/264631/jonatas-santo...
# 18132     264634  https://sofifa.com/player/264634/matias-cabrer...
# 15951     264638  https://sofifa.com/player/264638/guillermo-lar...
# 11055     264639  https://sofifa.com/player/264639/fernando-jose...
# 14393     264640  https://sofifa.com/player/264640/iman-basafa/2...
#
#             short_name                     long_name player_positions  \
# 509            Iniesta          Andrés Iniesta Luján          CM, CAM
# ...

# %%
duplicates = df.duplicated(subset='short_name')
print(duplicates.sum())
# Out:
# 1094

# %%
duplicates = df.duplicated(subset='long_name')
print(duplicates.sum())
# Out:
# 20

# %%
keeps = ['short_name','club_name']
duplicated_values=df[keeps]
duplicated_values = duplicated_values.duplicated().sum()
duplicated_values
#duplicated_values.to_csv('duplicated_fin.csv')
# Out:
# 25

# %%
df.isnull().sum().head(20)
# Out:
# sofifa_id                 0
# player_url                0
# short_name                0
# long_name                 0
# player_positions          0
# overall                   0
# potential                 0
# value_eur                74
# wage_eur                 61
# age                       0
# dob                       0
# height_cm                 0
# weight_kg                 0
# club_team_id             61
# club_name                61
# league_name              61
# league_level             61
# club_position            61
# club_jersey_number       61
# club_loaned_from      18137
# dtype: int64

# %%
df.dropna(subset=['value_eur'],inplace=True)

# %%
df.isnull().sum().head(20)
# Out:
# sofifa_id                 0
# player_url                0
# short_name                0
# long_name                 0
# player_positions          0
# overall                   0
# potential                 0
# value_eur                 0
# wage_eur                  0
# age                       0
# dob                       0
# height_cm                 0
# weight_kg                 0
# club_team_id              0
# club_name                 0
# league_name               0
# league_level              0
# club_position             0
# club_jersey_number        0
# club_loaned_from      18063
# dtype: int64

# %%
df['player_name'] = df['short_name'].str.cat(df['club_name'], sep=' ')

# %%
df['player_name']
# Out:
# 0                  L. Messi Paris Saint-Germain
# 1              R. Lewandowski FC Bayern München
# 2           Cristiano Ronaldo Manchester United
# 3                 Neymar Jr Paris Saint-Germain
# 4                  K. De Bruyne Manchester City
#                           ...
# 19234                        Song Defu Wuhan FC
# 19235                      C. Porter Derry City
# 19236                       N. Logue Finn Harps
# 19237                      L. Rudden Finn Harps
# 19238    E. Lalchhanchhuaha NorthEast United FC
# Name: player_name, Length: 19165, dtype: object

# %%
df = df.drop('short_name', axis=1)

# %%
df.head(5)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#                              long_name player_positions  overall  potential  \
# 0       Lionel Andrés Messi Cuccittini       RW, ST, CF       93         93
# 1                   Robert Lewandowski               ST       92         92
# 2  Cristiano Ronaldo dos Santos Aveiro           ST, LW       91         91
# 3        Neymar da Silva Santos Júnior          LW, CAM       91         91
# 4                      Kevin De Bruyne          CM, CAM       91         91
#
#      value_eur  wage_eur  age         dob  ...    cb   rcb    rb    gk  \
# ...

# %%
# Get the column names
columns = df.columns.tolist()

# Move the last column to the third position
columns.insert(2, columns.pop())

# Reorder the DataFrame columns
df = df[columns]

# %%
df.head(5)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#                            player_name                            long_name  \
# 0         L. Messi Paris Saint-Germain       Lionel Andrés Messi Cuccittini
# 1     R. Lewandowski FC Bayern München                   Robert Lewandowski
# 2  Cristiano Ronaldo Manchester United  Cristiano Ronaldo dos Santos Aveiro
# 3        Neymar Jr Paris Saint-Germain        Neymar da Silva Santos Júnior
# 4         K. De Bruyne Manchester City                      Kevin De Bruyne
#
#   player_positions  overall  potential    value_eur  wage_eur  age  ...   lcb  \
# ...

# %%
df.iloc[:, 15:30].isnull().sum()
# Out:
# league_name                      0
# league_level                     0
# club_position                    0
# club_jersey_number               0
# club_loaned_from             18063
# club_joined                   1102
# club_contract_valid_until        0
# nationality_id                   0
# nationality_name                 0
# nation_team_id               18467
# nation_position              18467
# nation_jersey_number         18467
# preferred_foot                   0
# weak_foot                        0
# skill_moves                      0
# dtype: int64

# %%
# Storing copy of DataFrame without the records that have missing values in value_eur
import numpy as np
cols_to_drop = []
for i in df.columns:
    missing = np.abs((df[i].count() - df[i].shape[0])/df[i].shape[0] * 100)
    if missing > 60:
        print('{} - {}%'.format(i, round(missing)))
        cols_to_drop.append(i)
dropped = df.drop(columns=cols_to_drop)
# Out:
# club_loaned_from - 94%
# nation_team_id - 96%
# nation_position - 96%
# nation_jersey_number - 96%
# player_tags - 93%
# goalkeeping_speed - 89%
# nation_logo_url - 96%

# %%
df = dropped

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                                   player_name  \
# 0                L. Messi Paris Saint-Germain
# 1            R. Lewandowski FC Bayern München
# ...

# %%
df.drop(['player_traits'],axis=1,inplace=True)

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                                   player_name  \
# 0                L. Messi Paris Saint-Germain
# 1            R. Lewandowski FC Bayern München
# ...

# %%
df.iloc[:, 15:30].isnull().sum()
# Out:
# league_name                     0
# league_level                    0
# club_position                   0
# club_jersey_number              0
# club_joined                  1102
# club_contract_valid_until       0
# nationality_id                  0
# nationality_name                0
# preferred_foot                  0
# weak_foot                       0
# skill_moves                     0
# international_reputation        0
# work_rate                       0
# body_type                       0
# real_face                       0
# dtype: int64

# %%
df['club_joined'] = pd.to_datetime(df['club_joined'])
df['club_joined'] = df['club_joined'].dt.year

df['dob'] = pd.to_datetime(df['dob'])
df['dob'] = df['dob'].dt.year

# %%
df['club_joined']
# Out:
# 0        2021.0
# 1        2014.0
# 2        2021.0
# 3        2017.0
# 4        2015.0
#           ...
# 19234    2021.0
# 19235    2021.0
# 19236    2021.0
# 19237    2021.0
# 19238    2021.0
# Name: club_joined, Length: 19165, dtype: float64

# %%
df.iloc[:,15:30].isnull().sum()
# Out:
# league_name                     0
# league_level                    0
# club_position                   0
# club_jersey_number              0
# club_joined                  1102
# club_contract_valid_until       0
# nationality_id                  0
# nationality_name                0
# preferred_foot                  0
# weak_foot                       0
# skill_moves                     0
# international_reputation        0
# work_rate                       0
# body_type                       0
# real_face                       0
# dtype: int64

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                                   player_name  \
# 0                L. Messi Paris Saint-Germain
# 1            R. Lewandowski FC Bayern München
# ...

# %%
df.to_csv('test.csv')

# %%
copy = df.copy()

# %%
unique_positions = df['player_positions'].unique()
unique_positions
# Out:
# array(['RW, ST, CF', 'ST', 'ST, LW', 'LW, CAM', 'CM, CAM', 'GK',
#        'CDM, CM', 'CF, ST', 'LM, CF, LW', 'CDM', 'CB', 'LW', 'RW',
#        'CDM, RB', 'CM', 'LW, RW', 'CAM', 'RW, LW', 'CAM, RM, RW',
#        'CM, LM', 'CB, CDM', 'CM, CDM', 'CF, CAM', 'LB', 'CM, CDM, CB',
#        'RB', 'RM, CF, LM', 'LB, LM', 'LW, CF', 'RW, RM', 'ST, RM, RW',
#        'CDM, CB', 'RB, LB', 'LM, RM, LW', 'CAM, CM, RW', 'CM, RM, ST',
#        'CAM, CF, CM', 'CAM, CM', 'CAM, CF', 'ST, LW, LM', 'ST, LW, RW',
#        'CF', 'CF, LW, CAM', 'RM, LM, RW', 'CM, CDM, CAM', 'LM, ST',
#        'RB, RWB', 'RB, RM', 'CF, ST, CAM', 'RB, RWB, RM', 'ST, RW',
#        'CB, LB', 'CAM, CM, CF', 'LW, CF, CAM', 'LW, LM, CAM', 'LM, LWB',
#        'RW, CAM', 'CAM, RM, ST', 'RM, LM', 'CAM, LW, CM', 'RW, LW, CAM',
#        'CB, RWB', 'CM, CAM, CDM', 'CAM, RM, LM', 'CM, CDM, LM',
#        'CF, RM, RW', 'ST, CF', 'LWB, LB, LM', 'LB, LWB, LM', 'LM, CM, RM',
# ...

# %%
sorted_positions = sorted(unique_positions)
combined_positions = ' '.join(sorted_positions)
print(combined_positions)
# Out:
# CAM CAM, CDM CAM, CDM, CM CAM, CDM, LM CAM, CDM, RM CAM, CDM, ST CAM, CF CAM, CF, CM CAM, CF, LM CAM, CF, LW CAM, CF, RM CAM, CF, RW CAM, CF, ST CAM, CM CAM, CM, CDM CAM, CM, CF CAM, CM, LM CAM, CM, LW CAM, CM, LWB CAM, CM, RM CAM, CM, RW CAM, CM, RWB CAM, CM, ST CAM, LM CAM, LM, CF CAM, LM, CM CAM, LM, LW CAM, LM, RM CAM, LM, RW CAM, LM, ST CAM, LW CAM, LW, CF CAM, LW, CM CAM, LW, LB CAM, LW, LM CAM, LW, RW CAM, LW, ST CAM, RB CAM, RM CAM, RM, CF CAM, RM, CM CAM, RM, LM CAM, RM, RB CAM, RM, RW CAM, RM, RWB CAM, RM, ST CAM, RW CAM, RW, CF CAM, RW, CM CAM, RW, LW CAM, RW, RM CAM, RW, ST CAM, RWB, CM CAM, ST CAM, ST, CDM CAM, ST, CF CAM, ST, CM CAM, ST, LM CAM, ST, LW CAM, ST, RM CAM, ST, RW CB CB, CAM CB, CDM CB, CDM, CM CB, CDM, LB CB, CDM, RB CB, CF CB, CM CB, CM, CDM CB, CM, RB CB, LB CB, LB, CDM CB, LB, CM CB, LB, LM CB, LB, LWB CB, LB, RB CB, LB, RM CB, LB, RWB CB, LM CB, LM, RM CB, LWB CB, LWB, LB CB, LWB, LM CB, LWB, RWB CB, RB CB, RB, CDM CB, RB, CM CB, RB, LB CB, RB, LM CB, R
# ...

# %%
#Create a DataFrame with the sorted positions and length column
positions_df = pd.DataFrame({'Sorted Positions': sorted_positions})
positions_df['Length of Sorted Positions'] = len(sorted_positions)

#Export to CSV
#positions_df.to_csv('positions.csv', index=False)

# %%
new_record=''
my_list=[]
print(len(combined_positions))
for c in combined_positions:
    if c in [',',' '] :
        if new_record:
            my_list.append(new_record)
            new_record=""

    
    if c not in [',',' '] :
        new_record+=c



            
print(my_list.__len__())
my_list
# Out:
# 7180
# 1858
# ['CAM',
#  'CAM',
#  'CDM',
#  'CAM',
#  'CDM',
#  'CM',
#  'CAM',
#  'CDM',
#  'LM',
#  'CAM',
#  'CDM',
#  'RM',
#  'CAM',
#  'CDM',
#  'ST',
#  'CAM',
#  'CF',
#  'CAM',
#  'CF',
#  'CM',
#  'CAM',
#  'CF',
#  'LM',
#  'CAM',
#  'CF',
#  'LW',
#  'CAM',
#  'CF',
#  'RM',
#  'CAM',
#  'CF',
#  'RW',
#  'CAM',
#  'CF',
#  'ST',
#  'CAM',
#  'CM',
#  'CAM',
#  'CM',
#  'CDM',
#  'CAM',
#  'CM',
#  'CF',
#  'CAM',
#  'CM',
#  'LM',
#  'CAM',
#  'CM',
#  'LW',
#  'CAM',
#  'CM',
#  'LWB',
#  'CAM',
#  'CM',
#  'RM',
#  'CAM',
#  'CM',
#  'RW',
#  'CAM',
#  'CM',
#  'RWB',
#  'CAM',
#  'CM',
#  'ST',
#  'CAM',
#  'LM',
#  'CAM',
#  'LM',
#  'CF',
#  'CAM',
#  'LM',
#  'CM',
#  'CAM',
#  'LM',
#  'LW',
#  'CAM',
#  'LM',
#  'RM',
#  'CAM',
#  'LM',
#  'RW',
#  'CAM',
#  'LM',
#  'ST',
#  'CAM',
#  'LW',
#  'CAM',
#  'LW',
#  'CF',
#  'CAM',
#  'LW',
#  'CM',
#  'CAM',
#  'LW',
#  'LB',
#  'CAM',
#  'LW',
#  'LM',
#  'CAM',
#  'LW',
#  'RW',
#  'CAM',
#  'LW',
#  'ST',
# ...

# %%
import numpy as np
my_set = set(my_list)
print(len(my_set))
# Out:
# 15

# %%
newlist = list(my_set)
unique_club_pos = df["club_position"].unique()
print(len(unique_club_pos))
# Convert the list to a NumPy array
unique_positions = np.array(newlist)

# Concatenate the pos array and arr array
new_pos = np.concatenate((unique_club_pos, unique_positions))
print(len(new_pos))

#for x in new_pos:
#    print(x)
# Out:
# 29
# 44

# %%
pos_unique = np.unique(new_pos)
len(pos_unique)
# Out:
# 29

# %%
one_df = pd.DataFrame()
sorted_pos_unique = sorted(pos_unique)
sorted_unique_club_pos = sorted(unique_club_pos)

one_df["unique"]=sorted_pos_unique
one_df["club_postion"]=sorted_unique_club_pos
one_df
# Out:
#    unique club_postion
# 0     CAM          CAM
# 1      CB           CB
# 2     CDM          CDM
# 3      CF           CF
# 4      CM           CM
# 5      GK           GK
# 6     LAM          LAM
# 7      LB           LB
# 8     LCB          LCB
# 9     LCM          LCM
# 10    LDM          LDM
# 11     LF           LF
# 12     LM           LM
# 13     LS           LS
# 14     LW           LW
# 15    LWB          LWB
# 16    RAM          RAM
# 17     RB           RB
# 18    RCB          RCB
# 19    RCM          RCM
# 20    RDM          RDM
# 21    RES          RES
# 22     RF           RF
# 23     RM           RM
# 24     RS           RS
# 25     RW           RW
# 26    RWB          RWB
# 27     ST           ST
# 28    SUB          SUB

# %% [markdown]
# # Handling missing values

# %%
drop_na = df.copy()
drop_na.dropna(inplace=True)
column_count = len(drop_na["pace"])
print (column_count)
drop_na.iloc[:,68:].isnull().sum()
# Out:
# 16020
# goalkeeping_kicking        0
# goalkeeping_positioning    0
# goalkeeping_reflexes       0
# ls                         0
# st                         0
# rs                         0
# lw                         0
# lf                         0
# cf                         0
# rf                         0
# rw                         0
# lam                        0
# cam                        0
# ram                        0
# lm                         0
# lcm                        0
# cm                         0
# rcm                        0
# rm                         0
# lwb                        0
# ldm                        0
# cdm                        0
# rdm                        0
# rwb                        0
# lb                         0
# lcb                        0
# cb                         0
# rcb                        0
# rb                         0
# gk                         0
# player_face_url            0
# club_logo_url              0
# ...

# %%
column_list = ["pace","shooting","passing","dribbling","defending","physic"]
data_types = drop_na[column_list].dtypes
data_types
# Out:
# pace         float64
# shooting     float64
# passing      float64
# dribbling    float64
# defending    float64
# physic       float64
# dtype: object

# %%
for column in column_list:
    drop_na[column] = pd.to_numeric(drop_na[column], errors='coerce').astype('int64')
drop_na.dtypes.head(40)
int_columns_count = drop_na.select_dtypes(include=['int64','int32']).shape[1]
print (int_columns_count)
column_count = len(drop_na["pace"])
print (column_count)
# Out:
# 51
# 16020

# %%
integer_columns = drop_na.select_dtypes(include=['int']).columns
integer_data = drop_na[integer_columns].copy()
integer_data.dropna(inplace=True)
int_columns_count = integer_data.select_dtypes(include=['int64','int32']).shape[1]
print(int_columns_count)
#print(integer_data.isnull().sum())
correlation_matrix = integer_data.corr()
correlation_matrix
# Out:
# 51
#                              sofifa_id   overall  potential       age  \
# sofifa_id                     1.000000 -0.504967   0.034602 -0.781722
# overall                      -0.504967  1.000000   0.639286  0.467196
# potential                     0.034602  0.639286   1.000000 -0.265077
# age                          -0.781722  0.467196  -0.265077  1.000000
# dob                           0.782024 -0.465378   0.266139 -0.994365
# height_cm                    -0.091132  0.067564   0.019401  0.074885
# weight_kg                    -0.198570  0.176871   0.000747  0.230857
# nationality_id                0.068447 -0.165476  -0.235682  0.049610
# weak_foot                    -0.150207  0.222200   0.142290  0.116076
# skill_moves                  -0.259088  0.458455   0.322159  0.172746
# international_reputation     -0.336462  0.478831   0.368309  0.228850
# pace                          0.158444  0.173234   0.255441 -0.205414
# ...

# %%
correlation = integer_data.corr()['pace'].abs().sort_values(ascending=False)
strong_corr_column = correlation.index[2]

strong_corr_column
correlation
# Out:
# pace                           1.000000
# movement_sprint_speed          0.972069
# movement_acceleration          0.958944
# movement_agility               0.696670
# movement_balance               0.524948
# dribbling                      0.492937
# skill_dribbling                0.488409
# mentality_positioning          0.407590
# attacking_crossing             0.405489
# height_cm                      0.399531
# skill_moves                    0.385398
# weight_kg                      0.358801
# attacking_finishing            0.350441
# skill_curve                    0.326477
# shooting                       0.323577
# skill_ball_control             0.314001
# power_strength                 0.310011
# defending                      0.296579
# attacking_volleys              0.282903
# defending_standing_tackle      0.279550
# defending_marking_awareness    0.275554
# mentality_interceptions        0.274565
# power_long_shots               0.270566
# ...

# %%
correlation = integer_data.corr()['shooting'].abs().sort_values(ascending=False)
strong_corr_column = correlation.index[2]

strong_corr_column
correlation
# Out:
# shooting                       1.000000
# attacking_finishing            0.967634
# power_long_shots               0.931232
# attacking_volleys              0.881692
# power_shot_power               0.866845
# mentality_positioning          0.862915
# mentality_penalties            0.798948
# dribbling                      0.778040
# skill_dribbling                0.770997
# mentality_vision               0.756871
# skill_curve                    0.729722
# skill_ball_control             0.728788
# passing                        0.667286
# skill_fk_accuracy              0.659988
# skill_moves                    0.605906
# mentality_composure            0.565300
# attacking_short_passing        0.528057
# attacking_crossing             0.516738
# movement_agility               0.499584
# overall                        0.491847
# movement_reactions             0.469444
# defending_sliding_tackle       0.457100
# defending_standing_tackle      0.420096
# ...

# %%
correlation = integer_data.corr()['passing'].abs().sort_values(ascending=False)
strong_corr_column = correlation.index[2]

strong_corr_column
correlation
# Out:
# passing                        1.000000
# attacking_short_passing        0.900519
# mentality_vision               0.885458
# skill_ball_control             0.849839
# skill_long_passing             0.849654
# dribbling                      0.847651
# attacking_crossing             0.822275
# skill_curve                    0.803770
# skill_dribbling                0.789082
# skill_fk_accuracy              0.749936
# mentality_composure            0.725106
# overall                        0.719219
# power_long_shots               0.716073
# mentality_positioning          0.678314
# shooting                       0.667286
# power_shot_power               0.661875
# movement_reactions             0.658796
# attacking_volleys              0.598305
# skill_moves                    0.578962
# attacking_finishing            0.566150
# movement_agility               0.516009
# mentality_penalties            0.513160
# potential                      0.446779
# ...

# %%
correlation = integer_data.corr()['dribbling'].abs().sort_values(ascending=False)
strong_corr_column = correlation.index[2]

strong_corr_column
correlation
# Out:
# dribbling                      1.000000
# skill_dribbling                0.972005
# skill_ball_control             0.923544
# passing                        0.847651
# mentality_vision               0.819843
# mentality_positioning          0.806882
# shooting                       0.778040
# skill_curve                    0.776733
# power_long_shots               0.760348
# attacking_crossing             0.738280
# attacking_short_passing        0.728659
# attacking_finishing            0.724620
# movement_agility               0.711631
# attacking_volleys              0.694552
# power_shot_power               0.680549
# mentality_composure            0.676156
# skill_moves                    0.670388
# overall                        0.667876
# skill_fk_accuracy              0.642518
# movement_reactions             0.602878
# mentality_penalties            0.587326
# skill_long_passing             0.584133
# movement_balance               0.532918
# ...

# %%
correlation = integer_data.corr()['defending'].abs().sort_values(ascending=False)
strong_corr_column = correlation.index[2]

strong_corr_column
correlation
# Out:
# defending                      1.000000
# defending_standing_tackle      0.977692
# mentality_interceptions        0.967727
# defending_marking_awareness    0.967615
# defending_sliding_tackle       0.963221
# mentality_aggression           0.666413
# physic                         0.543062
# attacking_finishing            0.495169
# skill_long_passing             0.435460
# shooting                       0.394894
# attacking_volleys              0.374929
# power_stamina                  0.366394
# power_strength                 0.359364
# mentality_penalties            0.358317
# overall                        0.354372
# movement_reactions             0.342095
# attacking_heading_accuracy     0.338765
# mentality_positioning          0.330294
# attacking_short_passing        0.311709
# movement_acceleration          0.303981
# pace                           0.296579
# power_jumping                  0.273561
# movement_sprint_speed          0.272290
# ...

# %%
correlation = integer_data.corr()['physic'].abs().sort_values(ascending=False)
strong_corr_column = correlation.index[2]

strong_corr_column
correlation
# Out:
# physic                         1.000000
# power_strength                 0.896819
# mentality_aggression           0.759247
# attacking_heading_accuracy     0.655750
# power_stamina                  0.602375
# weight_kg                      0.586062
# defending                      0.543062
# overall                        0.534805
# mentality_interceptions        0.517681
# defending_marking_awareness    0.512586
# movement_reactions             0.504168
# power_jumping                  0.503323
# height_cm                      0.499040
# defending_standing_tackle      0.474927
# dob                            0.450154
# age                            0.450074
# defending_sliding_tackle       0.446780
# mentality_composure            0.413152
# sofifa_id                      0.411220
# movement_balance               0.374260
# attacking_short_passing        0.309082
# skill_long_passing             0.282932
# movement_acceleration          0.244292
# ...

# %%
df.iloc[:,80:].isnull().sum()
# Out:
# cam                0
# ram                0
# lm                 0
# lcm                0
# cm                 0
# rcm                0
# rm                 0
# lwb                0
# ldm                0
# cdm                0
# rdm                0
# rwb                0
# lb                 0
# lcb                0
# cb                 0
# rcb                0
# rb                 0
# gk                 0
# player_face_url    0
# club_logo_url      0
# club_flag_url      0
# nation_flag_url    0
# dtype: int64

# %%
df.iloc[:,:40].isnull().sum()
# Out:
# sofifa_id                        0
# player_url                       0
# player_name                      0
# long_name                        0
# player_positions                 0
# overall                          0
# potential                        0
# value_eur                        0
# wage_eur                         0
# age                              0
# dob                              0
# height_cm                        0
# weight_kg                        0
# club_team_id                     0
# club_name                        0
# league_name                      0
# league_level                     0
# club_position                    0
# club_jersey_number               0
# club_joined                   1102
# club_contract_valid_until        0
# nationality_id                   0
# nationality_name                 0
# preferred_foot                   0
# weak_foot                        0
# skill_moves                      0
# international_reputation         0
# ...

# %%
import numpy as np

column_data = df["value_eur"]

# Calculate the IQR (interquartile range)
Q1 = np.percentile(column_data, 25)
Q3 = np.percentile(column_data, 75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_fence = Q1 - 1.5 * IQR
upper_fence = Q3 + 1.5 * IQR

# Find the outliers in the column
outliers = column_data[(column_data < lower_fence) | (column_data > upper_fence)]

# Print the outliers
sorted_outliers = outliers.sort_values(ascending=True)
print(sorted_outliers)
# Out:
# 2163      4300000.0
# 2971      4300000.0
# 2218      4300000.0
# 2232      4300000.0
# 2134      4300000.0
#            ...
# 4       125500000.0
# 3       129000000.0
# 9       129500000.0
# 29      137500000.0
# 6       194000000.0
# Name: value_eur, Length: 2235, dtype: float64

# %%
# Count the number of outliers above the upper fence
outliers_above = column_data[column_data > upper_fence].count()

# Count the number of outliers below the lower fence
outliers_below = column_data[column_data < lower_fence].count()
print(outliers_below/len(column_data) ,outliers_above/len(column_data))
# Out:
# 0.0 0.11661883642055831

# %%
copy=df.copy()

# %%
import numpy as np

column_data = copy["value_eur"]

winsor_percent = 15  # Set the winsorization percentile
lower_limit = np.percentile(column_data, winsor_percent)  # Calculate the lower winsorization limit
upper_limit = np.percentile(column_data, 100 - winsor_percent)  # Calculate the upper winsorization limit

# Apply winsorization using np.clip
column_data_winsorized = np.clip(column_data, lower_limit, upper_limit)

# Assign the winsorized column back to the DataFrame
copy["value_eur"] = column_data_winsorized

# %%
import numpy as np

# Assuming 'data' is your DataFrame and 'column_name' is the name of the column you want to analyze
column_data = copy["value_eur"]

# Calculate the IQR (interquartile range)
Q1 = np.percentile(column_data, 25)
Q3 = np.percentile(column_data, 75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find the outliers in the column
outliers = column_data[(column_data < lower_bound) | (column_data > upper_bound)]

# Print the outliers
print(outliers)
# Out:
# Series([], Name: value_eur, dtype: float64)

# %%
copy=df.copy()

# %%
# Sort the column in ascending order
sorted_data = copy.sort_values(by='pace', ascending=True)

# Print the sorted column
sorted_data
# Out:
#        sofifa_id                                         player_url  \
# 4184      220826  https://sofifa.com/player/220826/larry-vasquez...
# 11952     253583  https://sofifa.com/player/253583/ronny-montero...
# 11160     193166  https://sofifa.com/player/193166/guillermo-mad...
# 9805       53655  https://sofifa.com/player/53655/jay-bothroyd/2...
# 11057      50632  https://sofifa.com/player/50632/peter-clarke/2...
# ...          ...                                                ...
# 19210     261958  https://sofifa.com/player/261958/xiang-gao/220002
# 19216     263340  https://sofifa.com/player/263340/harvey-wiles-...
# 19225     259213  https://sofifa.com/player/259213/dylan-da-silv...
# 19227     259646  https://sofifa.com/player/259646/arsh-shaikh/2...
# 19231     261547  https://sofifa.com/player/261547/revanth-by/22...
#
#                                        player_name  \
# 4184                          L. Vásquez Junior FC
# ...

# %%
def func(col):
    for value,index in df[col].iteritems():
        previous_value = df[col].get(index - 1)
        next_value = df[col].get(index + 1)

        if pd.isnull(previous_value)and pd.isnull(value):
            copy[col] = copy[col].fillna(method='ffill')  # Forward filling
        elif pd.isnull(next_value)and pd.isnull(value):
            data[col] = data[col].fillna(method='bfill')  # Backward filling

# %%
cols=['pace','shooting','passing','dribbling','defending','physic']
copy[cols] = copy[cols].fillna(method='ffill')  # Forward filling
# Or
#data[column_name] = data[column_name].fillna(method='bfill')  # Backward filling
copy.iloc[:,:40].isnull().sum()
#print(sorted_data['pace'])
# Out:
# sofifa_id                        0
# player_url                       0
# player_name                      0
# long_name                        0
# player_positions                 0
# overall                          0
# potential                        0
# value_eur                        0
# wage_eur                         0
# age                              0
# dob                              0
# height_cm                        0
# weight_kg                        0
# club_team_id                     0
# club_name                        0
# league_name                      0
# league_level                     0
# club_position                    0
# club_jersey_number               0
# club_joined                   1102
# club_contract_valid_until        0
# nationality_id                   0
# nationality_name                 0
# preferred_foot                   0
# weak_foot                        0
# skill_moves                      0
# international_reputation         0
# ...

# %%
# return the sort
sorted_copy = copy.sort_values(by=copy.columns[0])

df=copy
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                                   player_name  \
# 0                L. Messi Paris Saint-Germain
# 1            R. Lewandowski FC Bayern München
# ...

# %%
df[cols].isnull().sum()
# Out:
# pace         0
# shooting     0
# passing      0
# dribbling    0
# defending    0
# physic       0
# dtype: int64

# %% [markdown]
# # Drop Uselss Columns

# %%
cols = ['player_url'
,'club_joined', 'club_team_id', 'club_jersey_number', 'nationality_id', 'ls', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk','st', 'lcm', 'player_face_url', 'club_logo_url', 'club_flag_url', 'nation_flag_url']
df = df.drop(columns=cols)

# %%
columns = ['overall', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
           'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy',
           'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve',
           'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration',
           'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance',
           'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
           'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision',
           'mentality_penalties', 'mentality_composure', 'defending_marking_awareness',
           'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving',
           'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes']

selected_columns = df[columns]

# Export the selected columns to a CSV file
selected_columns.to_csv('selected_columns.csv', index=False)

# %%
#Import Libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
data = pd.read_csv('selected_columns.csv')
target = data['overall']
features = data.drop('overall', axis=1)
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.33, random_state=44, shuffle =True)
#Applying Linear Regression Model 

LinearRegressionModel = LinearRegression()
LinearRegressionModel.fit(X_train, y_train)

print('Linear Regression Train Score is : ' , LinearRegressionModel.score(X_train, y_train))
print('Linear Regression Test Score is : ' , LinearRegressionModel.score(X_test, y_test))
# Out:
# Linear Regression Train Score is :  0.893882405834463
# Linear Regression Test Score is :  0.8930034891552799

# %%
y_pred = LinearRegressionModel.predict(X_test)
print('Predicted Value for Linear Regression is : ' , y_pred[:10])
# Out:
# Predicted Value for Linear Regression is :  [74.09336342 57.92409927 59.19366825 62.62246222 71.44469908 57.73322485
#  62.85446656 70.66779728 66.05575019 63.8653099 ]

# %%
print('Predicted Value for Linear Regression is : ' , y_test[:10])
# Out:
# Predicted Value for Linear Regression is :  2117     74
# 14484    61
# 15561    60
# 11922    64
# 3404     72
# 16610    58
# 16401    59
# 6508     68
# 7775     67
# 12391    63
# Name: overall, dtype: int64

# %%
df.to_csv('df.csv')

# %%
# 1) Does the player's age affect the wage that they take?
import matplotlib.pyplot as plt 
import seaborn as sns
# Does the player's age affect the wage that they take?
correlation = df['age'].corr(df['wage_eur'])
plt.scatter(df['age'], df['wage_eur'])
plt.xlabel('Age')
plt.ylabel('Wage (EUR)')
plt.title('Correlation between Age and Wage')
plt.show()

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_name', 'long_name', 'player_positions', 'overall',
#        'potential', 'value_eur', 'wage_eur', 'age', 'dob', 'height_cm',
#        'weight_kg', 'club_name', 'league_name', 'league_level',
#        'club_position', 'club_contract_valid_until', 'nationality_name',
#        'preferred_foot', 'weak_foot', 'skill_moves',
#        'international_reputation', 'work_rate', 'body_type', 'real_face',
#        'release_clause_eur', 'pace', 'shooting', 'passing', 'dribbling',
#        'defending', 'physic', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
# ...

# %%
# How does the international reputation of a player impact their wage?
# Relationship between International reputation and Wages
reputation_correlation = df['international_reputation'].corr(df['wage_eur'])
print('Correlation : ',reputation_correlation)
# Out:
# Correlation :  0.6769767864156077

# %%
# 2) Relationship between International reputation and Wages
fig, ax = plt.subplots(figsize=(10,5))
plt.scatter(data = df, x= 'international_reputation', y='wage_eur')
plt.xlabel("International Reputation") 
plt.ylabel("Wage in EUR")
plt.title("Reputation & wages in EUR", fontsize = 20)
plt.show()

# %%
# 3) Calculate the average overall rating for each level of international reputation
average_rating_by_reputation = df.groupby('international_reputation')['overall'].mean()

# Create a bar plot to visualize the impact
plt.figure(figsize=(8, 6))
average_rating_by_reputation.plot(kind='bar', color='blue')
plt.xlabel('International Reputation')
plt.ylabel('Average Overall Rating')
plt.title('Impact of International Reputation on Overall Rating')
plt.xticks(rotation=0)
plt.show()

# %%
# What are the countries that have the most number of players ?
country_players = df['nationality_name'].value_counts().head(10)
country_players
# Out:
# nationality_name
# England          1717
# Germany          1214
# Spain            1085
# France            980
# Argentina         956
# Brazil            897
# Japan             543
# Netherlands       439
# United States     413
# Poland            401
# Name: count, dtype: int64

# %%
# 4) What are the countries that have the most number of players ?
plt.figure(figsize=(8, 6))
sns.barplot(x=country_players.index, y=country_players.values, color="blue", capsize=.2)
plt.title('Number Players per country')
plt.xticks(rotation=45)
plt.show()

# %%
# What are the main common characteristics between most expensive players?
# Select the attribute columns to analyze (excluding the overall rating column)
attribute_columns = ['potential', 'height_cm', 'skill_moves', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'attacking_finishing']
# Calculate the correlation matrix
correlation_matrix = df[attribute_columns + ['value_eur']].corr()
# Get the correlation values between the attributes and overall rating
correlation_with_overall = correlation_matrix['value_eur']
# Sort the correlation values in descending order by their absolute values
sorted_correlation = correlation_with_overall.abs().sort_values(ascending=False)
# Print the attributes with high correlation
print(sorted_correlation)
# Out:
# value_eur              1.000000
# potential              0.527738
# dribbling              0.401065
# passing                0.401051
# shooting               0.288119
# skill_moves            0.257232
# attacking_finishing    0.217691
# physic                 0.214334
# defending              0.147152
# height_cm              0.010291
# Name: value_eur, dtype: float64

# %%
# 5) What are the main common characteristics between most expensive players?
# Select the attribute columns to analyze (excluding the market value column)
attribute_columns = ['height_cm', 'skill_moves', 'shooting', 'passing', 'dribbling', 'defending', 'physic']
# Create subplots for each attribute
fig, axes = plt.subplots(len(attribute_columns), 1, figsize=(8, 8 * len(attribute_columns)))

# Iterate through the attribute columns
for i, attribute in enumerate(attribute_columns):
    # Create a scatter plot with market value on the x-axis and the attribute on the y-axis
    axes[i].scatter(df['value_eur'], df[attribute], alpha=0.5)
    axes[i].set_xlabel('Market Value (EUR)')
    axes[i].set_ylabel(attribute)
    axes[i].set_title(f'{attribute} vs. Market Value')

# Adjust the spacing between subplots
plt.tight_layout()
# Show the plot
plt.show()

# %%
# Most 10 clubs have the highest average market value of players?
average_market_value = df.groupby('club_name')['value_eur'].mean()
# Find the top 10 clubs with the highest average market value
top_10_clubs = average_market_value.nlargest(10)
# Print the top 10 clubs and their average market values
for club, value in top_10_clubs.items():
    print(f"Club: {club}, Average Market Value: {value}")
# Out:
# Club: Manchester City, Average Market Value: 40609687.5
# Club: Paris Saint-Germain, Average Market Value: 37193939.39393939
# Club: FC Bayern München, Average Market Value: 34624107.14285714
# Club: Liverpool, Average Market Value: 31708333.333333332
# Club: Manchester United, Average Market Value: 30567575.757575758
# Club: Real Madrid CF, Average Market Value: 29926515.151515152
# Club: Juventus, Average Market Value: 29803846.153846152
# Club: Atlético de Madrid, Average Market Value: 29764843.75
# Club: Chelsea, Average Market Value: 28307575.757575758
# Club: FC Barcelona, Average Market Value: 25281818.181818184

# %%
# 6) Most 10 clubs have the highest average market value of players?
# Calculate the average market value for each club
average_market_value = df.groupby('club_name')['value_eur'].mean()
# Find the top 10 clubs with the highest average market value
top_10_clubs = average_market_value.nlargest(10)
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(top_10_clubs.index, top_10_clubs.values, color='blue')
plt.xlabel('Club')
plt.ylabel('Average Market Value')
plt.title('Top 10 Clubs with Highest Average Market Value')
plt.xticks(rotation=45)
plt.show()

# %%
# What is the most age category of the players?
# Define the age categories
age_categories = ['Under 20', '20-24', '25-29', '30-34', '35+']

# Categorize the players based on their age
df['age_category'] = pd.cut(df['age'], bins=[0, 20, 24, 29, 34, 100], labels=age_categories)

# Count the number of players in each age category
age_category_counts = df['age_category'].value_counts()

# Get the most common age category
most_common_age_category = age_category_counts.idxmax()

# Print the most common age category
print("Most common age category: ", most_common_age_category)
# Out:
# Most common age category:  25-29

# %%
# 7) What is the most age category of the players?
# Define the age categories
age_categories = ['Under 20', '20-24', '25-29', '30-34', '35+']
# Categorize the players based on their age
df['age_category'] = pd.cut(df['age'], bins=[0, 20, 24, 29, 34, 100], labels=age_categories)
# Count the number of players in each age category
age_category_counts = df['age_category'].value_counts()
# Create a bar plot
plt.figure(figsize=(10, 6))
age_category_counts.plot(kind='bar', color='blue')
plt.xlabel('Age Category')
plt.ylabel('Number of Players')
plt.title('Age Categories of Players')
plt.xticks(rotation=45)
# Show the plot
plt.show()

# %%
# 8) Is there a correlation between physics and shooting, passing, dribbling, defending and potential of the players?
df_x = df[['shooting', 'defending', 'passing', 'dribbling', 'pace', 'wage_eur', 'potential', 'overall']]
plt.figure(figsize=(9, 9))
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.4)
width = 3
height = 3
index = 1

for i in df_x.columns:
    plt.subplot(height, width, index)
    plt.scatter(x=df['physic'], y=df_x[i])
    plt.xlabel('physic')
    plt.ylabel(i)
    index += 1

plt.tight_layout()
plt.show()

# %%
# 9) Is there a correlation between height and shooting, passing, dribbling, defending and potential of the players?
df_x = df[['shooting', 'defending', 'passing', 'dribbling', 'pace', 'wage_eur', 'potential', 'overall']]
plt.figure(figsize=(9, 9))
plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.4,
                    hspace=0.4)

width = 3
height = 3
index = 1
for i in df_x.columns:
    plt.subplot(height, width, index)
    plt.scatter(x=df['height_cm'], y=df_x[i])
    plt.xlabel('height_cm')
    plt.ylabel(i)
    index += 1

# Show the plots
plt.show()

# %%
# 10) Is there a correlation between weight and shooting, passing, dribbling, defending and potential of the players?
df_x = df[['shooting', 'defending', 'passing', 'dribbling', 'pace', 'wage_eur', 'potential', 'overall']]

plt.figure(figsize=(9, 9))

plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.4,
                    hspace=0.4)
width = 3
height = 3
index = 1
for i in df_x.columns:
    plt.subplot(height, width, index)
    plt.scatter(x=df['weight_kg'], y=df_x[i])
    plt.xlabel('weight_kg')
    plt.ylabel(i)
    index += 1

# Show the plots
plt.show()

# %%
# What are preferred foot for players?
preferred_foot_counts = df['preferred_foot'].value_counts()
print(preferred_foot_counts)
# Out:
# preferred_foot
# Right    14616
# Left      4549
# Name: count, dtype: int64

# %%
# 11) What are preferred foot for players?
preferred_foot_counts = df['preferred_foot'].value_counts()
plt.figure(figsize=(6, 4))
plt.bar(preferred_foot_counts.index, preferred_foot_counts.values, color='blue')
plt.xlabel('Preferred Foot')
plt.ylabel('Number of Players')
plt.title('Preferred Foot Distribution')
plt.show()

# %%
# 12) Is there a correlation between a player's overall rating and their market value?
# Calculate the correlation between overall rating and market value
correlation = df['overall'].corr(df['value_eur'])
# Print the correlation value
print("Correlation between overall rating and market value:", correlation)
# Out:
# Correlation between overall rating and market value: 0.55468404579114

# %%
# Plotting the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df['overall'], df['value_eur'], alpha=0.5)
plt.xlabel('Overall Rating')
plt.ylabel('Market Value (in Euros)')
plt.title('Correlation between Overall Rating and Market Value')
plt.show()

# %%
# 13) What is the correlation between defender players and tall?
# Filter the DataFrame to include only defender players
defender_players = df[df['player_positions'].str.contains('CB')]
# Calculate the correlation between defender players' overall rating and height
correlation = defender_players['defending'].corr(defender_players['height_cm'])
# Print the correlation value
print("Correlation between defender players and height:", correlation)
# Out:
# Correlation between defender players and height: 0.15047590076117276

# %%
# Filter the DataFrame to include only defender players
defender_players = df[df['player_positions'].str.contains('CB')]
# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(defender_players['height_cm'], defender_players['defending'], color='blue')
plt.xlabel('Height (cm)')
plt.ylabel('Overall Rating')
plt.title('Correlation between Defender Players and Height')
plt.show()

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_name', 'long_name', 'player_positions', 'overall',
#        'potential', 'value_eur', 'wage_eur', 'age', 'dob', 'height_cm',
#        'weight_kg', 'club_name', 'league_name', 'league_level',
#        'club_position', 'club_contract_valid_until', 'nationality_name',
#        'preferred_foot', 'weak_foot', 'skill_moves',
#        'international_reputation', 'work_rate', 'body_type', 'real_face',
#        'release_clause_eur', 'pace', 'shooting', 'passing', 'dribbling',
#        'defending', 'physic', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
# ...

# %%
# 14) Which most 10 players have the highest potential?
# Sort the DataFrame by potential rating in descending order
top_players = df.nlargest(10, 'potential')

# Extract the relevant columns
player_names = top_players['long_name']
potential_ratings = top_players['potential']

# Print the top 10 players with the highest potential
for player, potential in zip(player_names, potential_ratings):
    print(f"Player: {player}, Potential Rating: {potential}")
# Out:
# Player: Kylian Mbappé Lottin, Potential Rating: 95
# Player: Lionel Andrés Messi Cuccittini, Potential Rating: 93
# Player: Jan Oblak, Potential Rating: 93
# Player: Gianluigi Donnarumma, Potential Rating: 93
# Player: Erling Braut Haaland, Potential Rating: 93
# Player: Robert Lewandowski, Potential Rating: 92
# Player: Marc-André ter Stegen, Potential Rating: 92
# Player: Frenkie de Jong, Potential Rating: 92
# Player: Trent Alexander-Arnold, Potential Rating: 92
# Player: Kai Lukas Havertz, Potential Rating: 92

# %%
# Sort the DataFrame by potential rating in descending order
top_players = df.nlargest(10, 'potential')
# Extract the relevant columns
player_names = top_players['long_name']
potential_ratings = top_players['potential']
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(player_names, potential_ratings, color='blue')
plt.xlabel('Player')
plt.ylabel('Potential Rating')
plt.title('Top 10 Players with Highest Potential')
plt.xticks(rotation=45)
plt.show()

# %%
# 15) Most players have the highest skill moves and weak foot rating?
# Filter the DataFrame to include only players with skill_moves and weak_foot ratings
filtered_players = df[(df['skill_moves'] == 5) & (df['weak_foot'] == 5)]

# Sort the filtered DataFrame by overall rating in descending order
sorted_players = filtered_players.sort_values('overall', ascending=False)

# Retrieve the top 10 players
top_players = sorted_players.head(10)

# Print the top 10 players with their attributes
for index, player in top_players.iterrows():
    print("Player:", player['long_name'])
    print("Overall Rating:", player['overall'])
    print("Skill Moves:", player['skill_moves'])
    print("Weak Foot:", player['weak_foot'])
    print()
# Out:
# Player: Neymar da Silva Santos Júnior
# Overall Rating: 91
# Skill Moves: 5
# Weak Foot: 5
#
# Player: Ousmane Dembélé
# Overall Rating: 83
# Skill Moves: 5
# Weak Foot: 5
#
# Player: Jesús Manuel Corona Ruíz
# Overall Rating: 82
# Skill Moves: 5
# Weak Foot: 5
#
# Player: Luís Carlos Almeida da Cunha
# Overall Rating: 81
# Skill Moves: 5
# Weak Foot: 5
#
# Player: Franck Bilal Ribéry
# Overall Rating: 79
# Skill Moves: 5
# Weak Foot: 5
#
# Player: Cesar Fernando Silva dos Santos
# Overall Rating: 75
# Skill Moves: 5
# Weak Foot: 5
#
# Player: Rayan Mathis Cherki
# Overall Rating: 73
# Skill Moves: 5
# Weak Foot: 5

# %%
# 15) Most players have the highest skill moves and weak foot rating?
# Filter the DataFrame to include only players with skill_moves and weak_foot ratings
filtered_players = df[(df['skill_moves'] == 5) & (df['weak_foot'] == 5)]

# Sort the filtered DataFrame by overall rating in descending order
sorted_players = filtered_players.sort_values('overall', ascending=False)

# Retrieve the top 10 players
top_players = sorted_players.head(10)

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(top_players['long_name'], top_players['overall'])
plt.xlabel('Player')
plt.ylabel('Overall Rating')
plt.title('Top 10 Players with Highest Skill Moves and Weak Foot Rating')
plt.xticks(rotation=45)
plt.show()

# %%
# 16) what are the best 10 players from speed 
# Sort the DataFrame by 'movement_sprint_speed' column in descending order
top_players_speed = df.sort_values('movement_sprint_speed', ascending=False).head(10)

# Retrieve the player names and their sprint speed ratings
player_names = top_players_speed['long_name']
player_speed = top_players_speed['movement_sprint_speed']

# Print the top 10 players with their sprint speed ratings
for name, speed in zip(player_names, player_speed):
    print(f"Player: {name}, Speed: {speed}")
# Out:
# Player: Kylian Mbappé Lottin, Speed: 97
# Player: Adama Traoré Diarra, Speed: 96
# Player: Alphonso Boyle Davies, Speed: 96
# Player: Gerrit Holtmann, Speed: 95
# Player: Vinícius José Paixão de Oliveira Júnior, Speed: 95
# Player: Achraf Hakimi Mouh, Speed: 95
# Player: Daniel James, Speed: 95
# Player: Przemysław Płacheta, Speed: 94
# Player: Erling Braut Haaland, Speed: 94
# Player: Kyle Walker, Speed: 94

# %%
# 16) what are the best 10 players from speed 
# Sort the DataFrame by 'movement_sprint_speed' column in descending order
top_players_speed = df.sort_values('movement_sprint_speed', ascending=False).head(10)

# Retrieve the player names and their speed ratings
player_names = top_players_speed['long_name']
player_speed = top_players_speed['movement_sprint_speed']

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(player_names, player_speed, color='blue')
plt.xlabel('Player')
plt.ylabel('Speed')
plt.title('Top 10 Players with Highest Speed')
plt.xticks(rotation=45)
plt.show()

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_name', 'long_name', 'player_positions', 'overall',
#        'potential', 'value_eur', 'wage_eur', 'age', 'dob', 'height_cm',
#        'weight_kg', 'club_name', 'league_name', 'league_level',
#        'club_position', 'club_contract_valid_until', 'nationality_name',
#        'preferred_foot', 'weak_foot', 'skill_moves',
#        'international_reputation', 'work_rate', 'body_type', 'real_face',
#        'release_clause_eur', 'pace', 'shooting', 'passing', 'dribbling',
#        'defending', 'physic', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
# ...

# %%
# 17) Which most 10 players have the highest potential?
# Sort the DataFrame by potential rating in descending order
top_players = df.nlargest(10, 'potential')

# Extract the relevant columns
player_names = top_players['long_name']
potential_ratings = top_players['potential']

# Print the top 10 players with the highest potential
for player, potential in zip(player_names, potential_ratings):
    print(f"Player: {player}, Potential Rating: {potential}")
# Out:
# Player: Kylian Mbappé Lottin, Potential Rating: 95
# Player: Lionel Andrés Messi Cuccittini, Potential Rating: 93
# Player: Jan Oblak, Potential Rating: 93
# Player: Gianluigi Donnarumma, Potential Rating: 93
# Player: Erling Braut Haaland, Potential Rating: 93
# Player: Robert Lewandowski, Potential Rating: 92
# Player: Marc-André ter Stegen, Potential Rating: 92
# Player: Frenkie de Jong, Potential Rating: 92
# Player: Trent Alexander-Arnold, Potential Rating: 92
# Player: Kai Lukas Havertz, Potential Rating: 92

# %%
# Sort the DataFrame by potential rating in descending order
top_players = df.nlargest(10, 'potential')

# Extract the relevant columns
player_names = top_players['long_name']
potential_ratings = top_players['potential']

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(player_names, potential_ratings, color='blue')
plt.xlabel('Player')
plt.ylabel('Potential Rating')
plt.title('Top 10 Players with Highest Potential')
plt.xticks(rotation=45)
plt.show()

# %%
# Sort the DataFrame by skill moves rating in descending order
top_skill_moves = df.nlargest(10, 'skill_moves')
# Extract the relevant columns
player_names = top_skill_moves['long_name']
skill_moves_ratings = top_skill_moves['skill_moves']
# Print the players with the highest skill moves rating
for player, rating in zip(player_names, skill_moves_ratings):
    print(f"Player: {player} - Skill Moves Rating: {rating}")
# Out:
# Player: Cristiano Ronaldo dos Santos Aveiro - Skill Moves Rating: 5
# Player: Neymar da Silva Santos Júnior - Skill Moves Rating: 5
# Player: Kylian Mbappé Lottin - Skill Moves Rating: 5
# Player: Ángel Fabián Di María Hernández - Skill Moves Rating: 5
# Player: Paul Pogba - Skill Moves Rating: 5
# Player: Jadon Sancho - Skill Moves Rating: 5
# Player: Thiago Alcântara do Nascimento - Skill Moves Rating: 5
# Player: Riyad Mahrez - Skill Moves Rating: 5
# Player: Roberto Firmino Barbosa de Oliveira - Skill Moves Rating: 5
# Player: Memphis Depay - Skill Moves Rating: 5

# %%
# 18) Most fastest player 
# Sort the DataFrame by skill moves rating in descending order
top_skill_moves = df.nlargest(10, 'skill_moves')
# Extract the relevant columns
player_names = top_skill_moves['long_name']
skill_moves_ratings = top_skill_moves['skill_moves']
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(player_names, skill_moves_ratings, color='blue')
plt.xlabel('Player')
plt.ylabel('Skill Moves Rating')
plt.title('Top Players by Skill Moves Rating')
plt.xticks(rotation=45)
plt.show()

# %%
# 19) What are the Leagues that have most valuable players?
# Calculate the average market value for each league
average_market_value = df.groupby('league_name')['value_eur'].mean()

# Sort the average market values in descending order
sorted_average_value = average_market_value.sort_values(ascending=False)

# Get the top 10 leagues with the highest average market values
top_10_leagues = sorted_average_value.head(10)

# Print the top 10 leagues with their average market values
print(top_10_leagues)
# Out:
# league_name
# English Premier League           1.403218e+07
# Spain Primera Division           1.150427e+07
# Italian Serie A                  9.429298e+06
# German 1. Bundesliga             8.644973e+06
# French Ligue 1                   7.347478e+06
# Ukrainian Premier League         5.689286e+06
# Russian Premier League           4.675061e+06
# Czech Republic Gambrinus Liga    4.284367e+06
# Portuguese Liga ZON SAGRES       3.990861e+06
# Campeonato Brasileiro Série A    3.872583e+06
# Name: value_eur, dtype: float64

# %%
# Calculate the average market value for each league
average_market_value = df.groupby('league_name')['value_eur'].mean()
# Sort the average market values in descending order
sorted_average_value = average_market_value.sort_values(ascending=False)
# Get the top 10 leagues with the highest average market values
top_10_leagues = sorted_average_value.head(10)
# Create a bar plot
plt.figure(figsize=(10, 6))
top_10_leagues.plot(kind='bar', color='blue')
plt.xlabel('League')
plt.ylabel('Average Market Value (in EUR)')
plt.title('Top 10 Leagues with Most Valuable Players')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize = (10,7))
plt.pie(df.preferred_foot.value_counts().values,labels= df.preferred_foot.value_counts().index,autopct='%1.2f%%')
plt.title('Football Players preferred Feet',color = 'black',fontsize = 15)
plt.legend()
plt.show()

# %%
position_counts = df['player_positions'].value_counts()
print(position_counts)
# Out:
# player_positions
# CB              2408
# GK              2124
# ST              1761
# CDM, CM          946
# CM               726
#                 ...
# CAM, CDM, ST       1
# CDM, RWB, CB       1
# ST, CAM, RW        1
# ST, CF, RM         1
# CDM, LM, LB        1
# Name: count, Length: 674, dtype: int64

# %%
top_positions = df['player_positions'].value_counts().head(20)

plt.figure(figsize=(10, 6))
top_positions.plot(kind='bar')
plt.xlabel('Player Positions')
plt.ylabel('Count')
plt.title('Most Common Player Positions (Top 20 Positions)')
plt.show()

# %%
# 20) What is the correlation between wage and clubs?
top_20_clubs = df['club_name'].value_counts().head(20).index
correlation = df[df['club_name'].isin(top_20_clubs)].groupby('club_name')['wage_eur'].mean()
plt.figure(figsize=(12, 6))
correlation.plot(kind='bar')
plt.xlabel('Club')
plt.ylabel('Average Wage (EUR)')
plt.title('Average Wage by Top 20 Clubs')
plt.xticks(rotation=90)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Assuming df contains both numeric and non-numeric columns
df.dropna(inplace=True)
non_numeric_columns = df.select_dtypes(exclude=['float64', 'int64']).columns

label_encoder = LabelEncoder()
for column in non_numeric_columns:
    df[column] = label_encoder.fit_transform(df[column])

# Extract the features for clustering

# Apply K-Means clustering
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(df)
labels = kmeans.labels_
centroids = kmeans.cluster_centers_
# Out:
# C:\Users\Samue\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
labels
# Out:
# array([2, 2, 1, ..., 0, 0, 0])

# %%
from sklearn.metrics import silhouette_score

# Calculate Silhouette Score
silhouette_avg = silhouette_score(df, labels)

print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: 0.687992473770685

# %%
centroids
# Out:
# array([[   350.03863622,   3525.21588946],
#        [   360.06197183,  85707.04225352],
#        [   391.91428571, 206785.71428571],
#        [   340.90773067,  29377.05735661]])

# %%
features = df[['club_name', 'wage_eur']]  # Update with your actual column names
plt.scatter(features.iloc[:, 0], features.iloc[:, 1], c=labels, cmap='viridis', s=50, alpha=0.8)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=200, label='Centroids')
plt.title('K-Means Clustering with Label Encoding')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Assuming df contains both numeric and non-numeric columns
df.dropna(inplace=True)
non_numeric_columns = df.select_dtypes(exclude=['float64', 'int64']).columns

label_encoder = LabelEncoder()
for column in non_numeric_columns:
    df[column] = label_encoder.fit_transform(df[column])

# Extract the features for clustering

# Apply K-Means clustering
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(features)
labels = kmeans.labels_
centroids = kmeans.cluster_centers_
# Out:
# C:\Users\Samue\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.scatter(features.iloc[:, 0], features.iloc[:, 1], c=labels, cmap='viridis', s=50, alpha=0.8)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=200, label='Centroids')
plt.title('K-Means Clustering with Label Encoding')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

# Assuming df contains both numeric and non-numeric columns
df.dropna(inplace=True)
non_numeric_columns = df.select_dtypes(exclude=['float64', 'int64']).columns

label_encoder = LabelEncoder()
for column in non_numeric_columns:
    df[column] = label_encoder.fit_transform(df[column])

# Extract the features for clustering

# Apply Agglomerative Clustering
agg_clustering = AgglomerativeClustering(n_clusters=4)
labels_agg = agg_clustering.fit_predict(df)

# Visualize clusters
plt.scatter(df.iloc[:, 0], df.iloc[:, 1], c=labels_agg, cmap='viridis', s=50, alpha=0.8)
plt.title('Agglomerative Hierarchical Clustering with Label Encoding')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
labels
# Out:
# array([2, 2, 2, ..., 0, 0, 0])

# %%
centroids
# Out:
# array([[   350.03863622,   3525.21588946],
#        [   360.06197183,  85707.04225352],
#        [   391.91428571, 206785.71428571],
#        [   340.90773067,  29377.05735661]])

# %%
from sklearn.metrics import silhouette_score

# Calculate Silhouette Score
silhouette_avg = silhouette_score(df, labels_agg)

print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: 0.8367971534544058

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.mixture import GaussianMixture
import matplotlib.pyplot as plt

# Assuming df contains both numeric and non-numeric columns
df.dropna(inplace=True)
non_numeric_columns = df.select_dtypes(exclude=['float64', 'int64']).columns

label_encoder = LabelEncoder()
for column in non_numeric_columns:
    df[column] = label_encoder.fit_transform(df[column])

# Extract the features for clustering

# Apply Gaussian Mixture Model
gmm = GaussianMixture(n_components=4, random_state=42)
labels_gmm = gmm.fit_predict(df)

# Visualize clusters
plt.scatter(df.iloc[:, 0], df.iloc[:, 1], c=labels_gmm, cmap='viridis', s=50, alpha=0.8)
plt.title('Gaussian Mixture Model Clustering with Label Encoding')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
labels
# Out:
# array([2, 2, 2, ..., 0, 0, 0])

# %%
from sklearn.metrics import silhouette_score

# Calculate Silhouette Score
silhouette_avg = silhouette_score(df, labels_gmm)

print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: 0.24937412128444308

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# Assuming df contains both numeric and non-numeric columns
df.dropna(inplace=True)
non_numeric_columns = df.select_dtypes(exclude=['float64', 'int64']).columns

label_encoder = LabelEncoder()
for column in non_numeric_columns:
    df[column] = label_encoder.fit_transform(df[column])

# Extract the features for clustering

# Apply DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
labels_dbscan = dbscan.fit_predict(df)

# Visualize clusters
plt.scatter(df.iloc[:, 0], df.iloc[:, 1], c=labels_dbscan, cmap='viridis', s=50, alpha=0.8)
plt.title('DBSCAN Clustering with Label Encoding')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
labels
# Out:
# array([2, 2, 2, ..., 0, 0, 0])

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# Assuming df contains both numeric and non-numeric columns
df.dropna(inplace=True)
non_numeric_columns = df.select_dtypes(exclude=['float64', 'int64']).columns

label_encoder = LabelEncoder()
for column in non_numeric_columns:
    df[column] = label_encoder.fit_transform(df[column])

# Extract the features for clustering

# Apply Agglomerative Clustering
agg_clustering = AgglomerativeClustering(n_clusters=4, linkage='ward')
labels_agg = agg_clustering.fit_predict(df)

# Visualize clusters with dendrogram
linked = linkage(df, 'ward')
dendrogram(linked, orientation='top', distance_sort='descending', show_leaf_counts=True)
plt.title('Agglomerative Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# %%
labels
# Out:
# array([2, 2, 2, ..., 0, 0, 0])

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import SpectralClustering
import matplotlib.pyplot as plt

# Assuming df contains both numeric and non-numeric columns
df.dropna(inplace=True)
non_numeric_columns = df.select_dtypes(exclude=['float64', 'int64']).columns

label_encoder = LabelEncoder()
for column in non_numeric_columns:
    df[column] = label_encoder.fit_transform(df[column])

# Extract the features for clustering

# Apply Spectral Clustering
spectral_clustering = SpectralClustering(n_clusters=4, random_state=42)
labels_spectral = spectral_clustering.fit_predict(df)

# Visualize clusters
plt.scatter(df.iloc[:, 0], df.iloc[:, 1], c=labels_spectral, cmap='viridis', s=50, alpha=0.8)
plt.title('Spectral Clustering with Label Encoding')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
# Out:
# C:\Users\Samue\anaconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:273: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
labels
# Out:
# array([2, 2, 1, ..., 0, 0, 0])

# %% [markdown]
# # Finish
